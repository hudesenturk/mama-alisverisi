# %%
mama=[{"cesit":"kedi maması","marka":"Reflex","agirlik":"15kg","fiyat":"764TL"},
      {"cesit":"kedi maması","marka":"Reflex","agirlik":"2kg","fiyat":"155TL"},
      {"cesit":"kedi maması","marka":"Reflex","agirlik":"1,5kg","fiyat":"140TL"},
      {"cesit":"kedi maması","marka":"Mera","agirlik":"10kg","fiyat":"2000TL"},
      {"cesit":"kedi maması","marka":"Mera","agirlik":"4kg","fiyat":"1100TL"},
      {"cesit":"kedi maması","marka":"Mera","agirlik":"2kg","fiyat":"750TL"},
      {"cesit":"kedi maması","marka":"Jungle","agirlik":"15kg","fiyat":"745TL"},
      {"cesit":"kedi maması","marka":"Jungle","agirlik":"1,5kg","fiyat":"124TL"},
      {"cesit":"kedi maması","marka":"Jungle","agirlik":"500gr","fiyat":"36TL"},
      {"cesit":"köpek maması","marka":"Goody","agirlik":"25kg","fiyat":"450TL"},
      {"cesit":"köpek maması","marka":"Goody","agirlik":"15kg","fiyat":"279TL"},
      {"cesit":"köpek maması","marka":"Goody","agirlik":"2kg","fiyat":"37TL"},
      {"cesit":"köpek maması","marka":"Purina","agirlik":"14kg","fiyat":"990TL"},
      {"cesit":"köpek maması","marka":"Purina","agirlik":"3kg","fiyat":"638TL"},
      {"cesit":"köpek maması","marka":"Purina","agirlik":"2,5kg","fiyat":"274TL"},
      {"cesit":"köpek maması","marka":"Felicia","agirlik":"15kg","fiyat":"900TL"},
      {"cesit":"köpek maması","marka":"Felicia","agirlik":"6kg","fiyat":"503TL"},
      {"cesit":"köpek maması","marka":"Felicia","agirlik":"3kg","fiyat":"265TL"},
      {"cesit":"kuş yemi","marka":"Goldwings","agirlik":"5kg","fiyat":"236TL"},
      {"cesit":"kuş yemi","marka":"Goldwings","agirlik":"1kg","fiyat":"58TL"},
      {"cesit":"kuş yemi","marka":"Goldwings","agirlik":"300gr","fiyat":"27TL"},
      {"cesit":"kuş yemi","marka":"Quik","agirlik":"6kg","fiyat":"200TL"},
      {"cesit":"kuş yemi","marka":"Quik","agirlik":"1kg","fiyat":"58TL"},
      {"cesit":"kuş yemi","marka":"Quik","agirlik":"500gr","fiyat":"43TL"},
      {"cesit":"kuş yemi","marka":"Gardenmix","agirlik":"5kg","fiyat":"227TL"},
      {"cesit":"kuş yemi","marka":"Gardenmix","agirlik":"1kg","fiyat":"45TL"},
      {"cesit":"kuş yemi","marka":"Gardenmix","agirlik":"500gr","fiyat":"26TL"}]

mama_liste=[]

for i in range(len(mama)):
    if mama[i]["cesit"] not in mama_liste:
        mama_liste.append(mama[i]["cesit"])

# kullanıcıya mama çeşidi seçtiriyoruz

while True:
    for i in range(len(mama_liste)):
        print(i+1,mama_liste[i])

    secim=int(input("Hangi mama çeşidini seçmek istiyorsunuz? "))-1

    break
# Birden fazla tekrar eden mama markalarını tek bir kez yazdırıyoruz

marka_liste=[]

for i in range(len(mama)):
    if mama[i]["marka"] not in marka_liste:
        marka_liste.append(mama[i]["marka"])

if secim==0:
    markalar=marka_liste[0:3]

elif secim==1:
    markalar=marka_liste[3:6]

elif secim==2:
    markalar=marka_liste[6:9]


# Seçilen hayvan türünün mama markalarını yazdırıyoruz

while True:
    for i in range(len(markalar)):
        print(i+1, markalar[i])

# Kullanıcıya marka seçtiriyoruz
    secilen_marka = int(input("Hangi markayı seçmek istiyorsunuz? ")) - 1

# Seçilen markanın ağırlık ve fiyat bilgilerini ekrana yazdırıyoruz
    for i in range(len(mama)):
        if mama[i]["cesit"] == mama_liste[secim] and mama[i]["marka"] == markalar[secilen_marka]:
            print("Ağırlık:", mama[i]["agirlik"])
            print("Fiyat:", mama[i]["fiyat"])
            print("Ağırlık:", mama[i+1]["agirlik"])
            print("Fiyat:", mama[i+1]["fiyat"])
            print("Ağırlık:", mama[i+2]["agirlik"])
            print("Fiyat:", mama[i+2]["fiyat"])
            break

    break
# Out:
# 1 kedi maması
# 2 köpek maması
# 3 kuş yemi
# Hangi mama çeşidini seçmek istiyorsunuz? 2
# 1 Goody
# 2 Purina
# 3 Felicia
# Hangi markayı seçmek istiyorsunuz? 3
# Ağırlık: 15kg
# Fiyat: 900TL
# Ağırlık: 6kg
# Fiyat: 503TL
# Ağırlık: 3kg
# Fiyat: 265TL
